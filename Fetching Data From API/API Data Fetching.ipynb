# %%
import pandas as pd
import requests

import warnings
warnings.filterwarnings('ignore')

# %%
response = requests.get('https://api.themoviedb.org/3/discover/tv?api_key=bc26db49282444b8ceed2c03c660ef44&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'backdrop_path': '/q3jHCb4dMfYF6ojikKuHd6LscxC.jpg',
#    'first_air_date': '2021-06-09',
#    'genre_ids': [18, 10765],
#    'id': 84958,
#    'name': 'Loki',
#    'origin_country': ['US'],
#    'original_language': 'en',
#    'original_name': 'Loki',
#    'overview': 'After stealing the Tesseract during the events of “Avengers: Endgame,” an alternate version of Loki is brought to the mysterious Time Variance Authority, a bureaucratic organization that exists outside of time and space and monitors the timeline. They give Loki a choice: face being erased from existence due to being a “time variant” or help fix the timeline and stop a greater threat.',
#    'popularity': 3603.662,
#    'poster_path': '/voHUmluYmKyleFkTu3lOXQG702u.jpg',
#    'vote_average': 8.2,
#    'vote_count': 10451},
#   {'backdrop_path': '/jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg',
#    'first_air_date': '1952-12-26',
#    'genre_ids': [10763],
#    'id': 94722,
#    'name': 'Tagesschau',
# ...

# %%
response.json()['results']
# Out:
# [{'backdrop_path': '/q3jHCb4dMfYF6ojikKuHd6LscxC.jpg',
#   'first_air_date': '2021-06-09',
#   'genre_ids': [18, 10765],
#   'id': 84958,
#   'name': 'Loki',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_name': 'Loki',
#   'overview': 'After stealing the Tesseract during the events of “Avengers: Endgame,” an alternate version of Loki is brought to the mysterious Time Variance Authority, a bureaucratic organization that exists outside of time and space and monitors the timeline. They give Loki a choice: face being erased from existence due to being a “time variant” or help fix the timeline and stop a greater threat.',
#   'popularity': 3603.662,
#   'poster_path': '/voHUmluYmKyleFkTu3lOXQG702u.jpg',
#   'vote_average': 8.2,
#   'vote_count': 10451},
#  {'backdrop_path': '/jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg',
#   'first_air_date': '1952-12-26',
#   'genre_ids': [10763],
#   'id': 94722,
#   'name': 'Tagesschau',
#   'origin_country': ['DE'],
# ...

# %%
df = pd.DataFrame(response.json())
df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'backdrop_path': '/q3jHCb4dMfYF6ojikKuHd6Lscx...         7932
# 1      1  {'backdrop_path': '/jWXrQstj7p3Wl5MfYWY6IHqRpD...         7932
# 2      1  {'backdrop_path': '/l7LRGYJY3NzIGBlpvHpMsNXHbm...         7932
# 3      1  {'backdrop_path': '/218ZehBKlH8efPRRccmB7bu0oL...         7932
# 4      1  {'backdrop_path': '/9TXcHOeCsM8W3ZKKIKjdYUsRSe...         7932
# 5      1  {'backdrop_path': '/9xxLWtnFxkpJ2h1uthpvCRK6vt...         7932
# 6      1  {'backdrop_path': '/oOce9hLMVFubjAJliau4kiSNPn...         7932
# 7      1  {'backdrop_path': '/5MkBAawsj7O9zitVtzMXagyrIB...         7932
# 8      1  {'backdrop_path': '/4w3AZvQMdzOS7oXXrrPnRD59dB...         7932
# 9      1  {'backdrop_path': '/aDRIKJuB63tuJUZf1O4mRmbMTV...         7932
# 10     1  {'backdrop_path': '/2N4LXvTkUwPRkbvyzdmzvtnCHg...         7932
# 11     1  {'backdrop_path': '/i4n8ZKmCUaxcGMkPhm12selZif...         7932
# ...

# %%
df = pd.DataFrame(response.json()['results'])
df
# Out:
#                        backdrop_path first_air_date              genre_ids  \
# 0   /q3jHCb4dMfYF6ojikKuHd6LscxC.jpg     2021-06-09            [18, 10765]
# 1   /jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg     1952-12-26                [10763]
# 2   /l7LRGYJY3NzIGBlpvHpMsNXHbm5.jpg     2023-01-09            [10751, 35]
# 3   /218ZehBKlH8efPRRccmB7bu0oLQ.jpg     2023-09-25  [35, 9648, 10766, 18]
# 4   /9TXcHOeCsM8W3ZKKIKjdYUsRSeq.jpg     2017-07-17               [80, 18]
# 5   /9xxLWtnFxkpJ2h1uthpvCRK6vta.jpg     1999-09-20         [80, 18, 9648]
# 6   /oOce9hLMVFubjAJliau4kiSNPnW.jpg     1990-09-13               [80, 18]
# 7   /5MkBAawsj7O9zitVtzMXagyrIBw.jpg     2023-01-30            [18, 10766]
# 8   /4w3AZvQMdzOS7oXXrrPnRD59dBr.jpg     2002-11-04                [10767]
# 9   /aDRIKJuB63tuJUZf1O4mRmbMTVw.jpg     1999-09-30                [10764]
# 10  /2N4LXvTkUwPRkbvyzdmzvtnCHgR.jpg     2023-07-25                     []
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 7922):
    response = requests.get(f"https://api.themoviedb.org/3/discover/tv?api_key=bc26db49282444b8ceed2c03c660ef44&page={i}")

    # Get the results from the API response
    results = response.json().get('results')

    # If the results are not None, add them to the DataFrame
    if results is not None:
        tem_df = pd.DataFrame(results)
        df = df.append(tem_df, ignore_index=True)

# %%
df.head()
# Out:
#                       backdrop_path first_air_date              genre_ids  \
# 0  /q3jHCb4dMfYF6ojikKuHd6LscxC.jpg     2021-06-09            [18, 10765]
# 1  /jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg     1952-12-26                [10763]
# 2  /l7LRGYJY3NzIGBlpvHpMsNXHbm5.jpg     2023-01-09            [10751, 35]
# 3  /218ZehBKlH8efPRRccmB7bu0oLQ.jpg     2023-09-25  [35, 9648, 10766, 18]
# 4  /9TXcHOeCsM8W3ZKKIKjdYUsRSeq.jpg     2017-07-17               [80, 18]
#
#        id              name origin_country original_language  \
# 0   84958              Loki           [US]                en
# 1   94722        Tagesschau           [DE]                de
# 2  218145      Mom for rent           [SK]                sk
# 3  219109     Elas por Elas           [BR]                pt
# 4   72879  Tomorrow is Ours           [FR]                fr
#
#             original_name                                           overview  \
# ...

# %%
df.to_csv('movies_review.csv')

# %%
df = pd.read_csv('movies_review.csv')
df.head()
# Out:
#    Unnamed: 0                     backdrop_path first_air_date  \
# 0           0  /q3jHCb4dMfYF6ojikKuHd6LscxC.jpg     2021-06-09
# 1           1  /jWXrQstj7p3Wl5MfYWY6IHqRpDb.jpg     1952-12-26
# 2           2  /l7LRGYJY3NzIGBlpvHpMsNXHbm5.jpg     2023-01-09
# 3           3  /218ZehBKlH8efPRRccmB7bu0oLQ.jpg     2023-09-25
# 4           4  /9TXcHOeCsM8W3ZKKIKjdYUsRSeq.jpg     2017-07-17
#
#                genre_ids      id              name origin_country  \
# 0            [18, 10765]   84958              Loki         ['US']
# 1                [10763]   94722        Tagesschau         ['DE']
# 2            [10751, 35]  218145      Mom for rent         ['SK']
# 3  [35, 9648, 10766, 18]  219109     Elas por Elas         ['BR']
# 4               [80, 18]   72879  Tomorrow is Ours         ['FR']
#
#   original_language           original_name  \
# 0                en                    Loki
# 1                de              Tagesschau
# 2                sk        Mama na prenájom
# ...
